# %%
import sys
import numpy as np
import os 
import line_profiler
print(os.getcwd())
os.chdir("/home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/")
sys.path.append("./dynamic_model/")
# sys.path.append("./MISC/exploratory_analysis/")
# sys.path.append("./MISC//")
from simulation.class_simulation import Simulation
from agents.class_sounds import EchoSound, DirectSound
from agents.class_bats import Bat
# from simulation_and_plotting.single_bat_plotter import visualize
from supporting_files.utilities import load_parameters
from supporting_files.snr_implementation import given_sound_objects_return_detected_sounds, is_signal_heard, get_temporal_masking_function_based_on_sound, generate_sound_profile
from supporting_files.vectors import Vector
# %load_ext line_profiler

OUTPUT_DIR = r"./dynamic_model/profiling/dump_files/"
PARAMETER_FILE_DIR = r"./dynamic_model/paramsets/common_parameters.json"
PARAMETER_DF = load_parameters(PARAMETER_FILE_DIR)
sim = Simulation(PARAMETER_DF, OUTPUT_DIR)
# Out:
# /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/profiling

# %%
OUTPUT_DIR = r"./dynamic_model/profiling/dump_files/"
PARAMETER_FILE_DIR = r"./dynamic_model/paramsets/common_parameters.json"
PARAMETER_DF = load_parameters(PARAMETER_FILE_DIR)
PARAMETER_DF["SIM_DURATION"]= [3]
sim = Simulation(PARAMETER_DF, OUTPUT_DIR)

# %%
# %lprun -f Simulation.run sim.run()
# Out:
# 1.0471975511965976 0.0
# angles in hearing range [-60. -30.   0.  30.  60.]
# bat call time 0.004
# 1.0471975511965976 0.1019872641178652
# angles in hearing range [-54.1565602 -24.1565602   5.8434398  35.8434398  65.8434398]
#
# bat call time 0.059
# 1.0471975511965976 0.1019872641178652
# angles in hearing range [-54.1565602 -24.1565602   5.8434398  35.8434398  65.8434398]
#
# bat call time 0.164
# 1.0471975511965976 0.1019872641178652
# angles in hearing range [-54.1565602 -24.1565602   5.8434398  35.8434398  65.8434398]
#
# bat call time 0.215
# 1.0471975511965976 0.1019872641178652
# angles in hearing range [-54.1565602 -24.1565602   5.8434398  35.8434398  65.8434398]
#
# bat call time 0.266
# 1.0471975511965976 0.1019872641178652
# angles in hearing range [-54.1565602 -24.1565602   5.8434398  35.8434398  65.8434398]
#
# bat call time 0.323
# 1.0471975511965976 0.1019872641178652
# angles in hearing range [-54.1565602 -24.1565602   5.8434398  35.8434398  65.8434398]
#
# bat call time 0.376
# 1.0471975511965976 0.1019872641178652
# angles in hearing range [-54.1565602 -24.1565602   5.8434398  35.8434398  65.8434398]
#
# bat call time 0.425
# 1.0471975511965976 0.1019872641178652
# angles in hearing range [-54.1565602 -24.1565602   5.8434398  35.8434398  65.8434398]
#
# bat call time 0.482
# 1.0471975511965976 0.1019872641178652
# angles in hearing range [-54.1565602 -24.1565602   5.8434398  35.8434398  65.8434398]
#
# bat call time 0.54
# 1.0471975511965976 0.1019872641178652
# angles in hearing range [-54.1565602 -24.1565602   5.8434398  35.8434398  65.8434398]
# bat call time 0.581
# 1.0471975511965976 0.005993823995327058
# angles in hearing range [-59.65657918 -29.65657918   0.34342082  30.34342082  60.34342082]
# bat call time 0.626
# 1.0471975511965976 -0.24902673984738768
# angles in hearing range [-74.26818118 -44.26818118 -14.26818118  15.73181882  45.73181882]
# bat call time 0.724
# 1.0471975511965976 -0.498037644445131
# angles in hearing range [-88.53545507 -58.53545507 -28.53545507   1.46454493  31.46454493]
# bat call time 0.82
# 1.0471975511965976 -0.7710290507586229
# angles in hearing range [-104.17671049  -74.17671049  -44.17671049  -14.17671049   15.82328951]
# bat call time 0.924
# 1.0471975511965976 -1.056047546820604
# angles in hearing range [-120.5070674  -90.5070674  -60.5070674  -30.5070674   -0.5070674]
# bat call time 1.032
# 1.0471975511965976 -1.3260719784985273
# angles in hearing range [-135.9783277 -105.9783277  -75.9783277  -45.9783277  -15.9783277]
# bat call time 1.135
# 1.0471975511965976 -1.5810516388983908
# angles in hearing range [-150.5875861 -120.5875861  -90.5875861  -60.5875861  -30.5875861]
#
# bat call time 1.233
# 1.0471975511965976 -1.5810516388983908
# angles in hearing range [-150.5875861 -120.5875861  -90.5875861  -60.5875861  -30.5875861]
#
# bat call time 1.339
# 1.0471975511965976 -1.5810516388983908
# angles in hearing range [-150.5875861 -120.5875861  -90.5875861  -60.5875861  -30.5875861]
#
# bat call time 1.397
# 1.0471975511965976 -1.5810516388983908
# angles in hearing range [-150.5875861 -120.5875861  -90.5875861  -60.5875861  -30.5875861]
#
# bat call time 1.456
# 1.0471975511965976 -1.5810516388983908
# angles in hearing range [-150.5875861 -120.5875861  -90.5875861  -60.5875861  -30.5875861]
#
# bat call time 1.501
# 1.0471975511965976 -1.5810516388983908
# angles in hearing range [-150.5875861 -120.5875861  -90.5875861  -60.5875861  -30.5875861]
#
# bat call time 1.547
# 1.0471975511965976 -1.5810516388983908
# angles in hearing range [-150.5875861 -120.5875861  -90.5875861  -60.5875861  -30.5875861]
#
# bat call time 1.591
# 1.0471975511965976 -1.5810516388983908
# angles in hearing range [-150.5875861 -120.5875861  -90.5875861  -60.5875861  -30.5875861]
#
# bat call time 1.65
# 1.0471975511965976 -1.5810516388983908
# angles in hearing range [-150.5875861 -120.5875861  -90.5875861  -60.5875861  -30.5875861]
# bat call time 1.696
# 1.0471975511965976 -1.6770835916130795
# angles in hearing range [-156.08981169 -126.08981169  -96.08981169  -66.08981169  -36.08981169]
# bat call time 1.741
# 1.0471975511965976 -1.9140943311952279
# angles in hearing range [-169.66952677 -139.66952677 -109.66952677  -79.66952677  -49.66952677]
# bat call time 1.833
# 1.0471975511965976 -2.151074942617085
# angles in hearing range [ 176.75248437 -153.24751563 -123.24751563  -93.24751563  -63.24751563]
# bat call time 1.925
# 1.0471975511965976 -2.409094328774433
# angles in hearing range [ 161.96906251 -168.03093749 -138.03093749 -108.03093749  -78.03093749]
# bat call time 2.024
# 1.0471975511965976 -2.649104834089645
# angles in hearing range [ 148.21747352  178.21747352 -151.78252648 -121.78252648  -91.78252648]
# bat call time 2.117
# 1.0471975511965976 -2.895129093655306
# angles in hearing range [ 134.12132179  164.12132179 -165.87867821 -135.87867821 -105.87867821]
# bat call time 2.212
# 1.0471975511965976 -3.1291318920170395
# angles in hearing range [ 120.71394905  150.71394905 -179.28605095 -149.28605095 -119.28605095]
# bat call time 2.303
# 1.0471975511965976 2.899088054121057
# angles in hearing range [ 106.10550994  136.10550994  166.10550994 -163.89449006 -133.89449006]
#
# bat call time 2.401
# 1.0471975511965976 2.899088054121057
# angles in hearing range [ 106.10550994  136.10550994  166.10550994 -163.89449006 -133.89449006]
#
# bat call time 2.505
# 1.0471975511965976 2.899088054121057
# angles in hearing range [ 106.10550994  136.10550994  166.10550994 -163.89449006 -133.89449006]
#
# bat call time 2.554
# 1.0471975511965976 2.899088054121057
# angles in hearing range [ 106.10550994  136.10550994  166.10550994 -163.89449006 -133.89449006]
#
# bat call time 2.611
# 1.0471975511965976 2.899088054121057
# angles in hearing range [ 106.10550994  136.10550994  166.10550994 -163.89449006 -133.89449006]
#
# bat call time 2.67
# 1.0471975511965976 2.899088054121057
# angles in hearing range [ 106.10550994  136.10550994  166.10550994 -163.89449006 -133.89449006]
#
# bat call time 2.717
# 1.0471975511965976 2.899088054121057
# angles in hearing range [ 106.10550994  136.10550994  166.10550994 -163.89449006 -133.89449006]
#
# bat call time 2.772
# 1.0471975511965976 2.899088054121057
# angles in hearing range [ 106.10550994  136.10550994  166.10550994 -163.89449006 -133.89449006]
#
# bat call time 2.832
# 1.0471975511965976 2.899088054121057
# angles in hearing range [ 106.10550994  136.10550994  166.10550994 -163.89449006 -133.89449006]
#
# bat call time 2.881
# 1.0471975511965976 2.899088054121057
# angles in hearing range [ 106.10550994  136.10550994  166.10550994 -163.89449006 -133.89449006]
# bat call time 2.924
# 1.0471975511965976 2.767098988775479
# angles in hearing range [  98.54309355  128.54309355  158.54309355 -171.45690645 -141.45690645]
# bat call time 2.981
# 1.0471975511965976 2.5181226276575757
# angles in hearing range [  84.27779886  114.27779886  144.27779886  174.27779886 -155.72220114]
# bat call time 3.077
# 1.0471975511965976 2.2721430674143805
# angles in hearing range [  70.18420821  100.18420821  130.18420821  160.18420821 -169.81579179]
# bat call time 3.172
# 1.0471975511965976 2.026097140350677
# angles in hearing range [ 56.08681503  86.08681503 116.08681503 146.08681503 176.08681503]
# bat call time 3.267
# 1.0471975511965976 1.7921029464415557
# angles in hearing range [ 42.67993528  72.67993528 102.67993528 132.67993528 162.67993528]
# bat call time 3.358
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 3.464
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 3.571
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 3.629
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 3.68
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 3.738
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 3.793
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 3.845
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 3.905
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 3.955
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.015
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.071
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.127
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.168
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.216
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.257
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.315
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.366
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.421
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.476
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.536
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.58
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.625
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.685
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.745
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.789
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.849
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.902
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.948
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 4.994
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 5.041
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 5.096
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 5.156
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 5.21
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 5.26
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 5.318
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
#
# bat call time 5.369
# 1.0471975511965976 1.5131030974990336
# angles in hearing range [ 26.69442145  56.69442145  86.69442145 116.69442145 146.69442145]
# bat call time 5.42
# 1.0471975511965976 1.6361120809137408
# angles in hearing range [ 33.74231705  63.74231705  93.74231705 123.74231705 153.74231705]
# bat call time 5.474
# 1.0471975511965976 1.9211022272978575
# angles in hearing range [ 50.07104964  80.07104964 110.07104964 140.07104964 170.07104964]
# bat call time 5.582
# 1.0471975511965976 2.2091536088491868
# angles in hearing range [  66.57517808   96.57517808  126.57517808  156.57517808 -173.42482192]
#
# bat call time 5.691
# 1.0471975511965976 2.2091536088491868
# angles in hearing range [  66.57517808   96.57517808  126.57517808  156.57517808 -173.42482192]
#
# bat call time 5.784
# 1.0471975511965976 2.2091536088491868
# angles in hearing range [  66.57517808   96.57517808  126.57517808  156.57517808 -173.42482192]
#
# bat call time 5.828
# 1.0471975511965976 2.2091536088491868
# angles in hearing range [  66.57517808   96.57517808  126.57517808  156.57517808 -173.42482192]
#
# bat call time 5.871
# 1.0471975511965976 2.2091536088491868
# angles in hearing range [  66.57517808   96.57517808  126.57517808  156.57517808 -173.42482192]
#
# bat call time 5.913
# 1.0471975511965976 2.2091536088491868
# angles in hearing range [  66.57517808   96.57517808  126.57517808  156.57517808 -173.42482192]
#
# bat call time 5.962
# 1.0471975511965976 2.2091536088491868
# angles in hearing range [  66.57517808   96.57517808  126.57517808  156.57517808 -173.42482192]
#
# bat call time 6.01
# 1.0471975511965976 2.2091536088491868
# angles in hearing range [  66.57517808   96.57517808  126.57517808  156.57517808 -173.42482192]
#
# bat call time 6.067
# 1.0471975511965976 2.2091536088491868
# angles in hearing range [  66.57517808   96.57517808  126.57517808  156.57517808 -173.42482192]
#
# bat call time 6.112
# 1.0471975511965976 2.2091536088491868
# angles in hearing range [  66.57517808   96.57517808  126.57517808  156.57517808 -173.42482192]
#
# bat call time 6.158
# 1.0471975511965976 2.2091536088491868
# angles in hearing range [  66.57517808   96.57517808  126.57517808  156.57517808 -173.42482192]
#
# bat call time 6.212
# 1.0471975511965976 2.2091536088491868
# angles in hearing range [  66.57517808   96.57517808  126.57517808  156.57517808 -173.42482192]
#
# bat call time 6.253
# 1.0471975511965976 2.2091536088491868
# angles in hearing range [  66.57517808   96.57517808  126.57517808  156.57517808 -173.42482192]
#
# bat call time 6.303
# 1.0471975511965976 2.2091536088491868
# angles in hearing range [  66.57517808   96.57517808  126.57517808  156.57517808 -173.42482192]
#
# bat call time 6.363
# 1.0471975511965976 2.2091536088491868
# angles in hearing range [  66.57517808   96.57517808  126.57517808  156.57517808 -173.42482192]
#
# bat call time 6.41
# 1.0471975511965976 2.2091536088491868
# angles in hearing range [  66.57517808   96.57517808  126.57517808  156.57517808 -173.42482192]
#
# bat call time 6.459
# 1.0471975511965976 2.2091536088491868
# angles in hearing range [  66.57517808   96.57517808  126.57517808  156.57517808 -173.42482192]
# bat call time 6.513
# 1.0471975511965976 2.0681246615571496
# angles in hearing range [ 58.49481461  88.49481461 118.49481461 148.49481461 178.49481461]
# bat call time 6.573
# 1.0471975511965976 1.8221039574141245
# angles in hearing range [ 44.39886659  74.39886659 104.39886659 134.39886659 164.39886659]
# bat call time 6.668
# 1.0471975511965976 1.5461063645266655
# angles in hearing range [ 28.58536937  58.58536937  88.58536937 118.58536937 148.58536937]
# bat call time 6.773
# 1.0471975511965976 1.291085159584065
# angles in hearing range [ 13.97373064  43.97373064  73.97373064 103.97373064 133.97373064]
# bat call time 6.871
# 1.0471975511965976 1.5611053751569843
# angles in hearing range [ 29.44474937  59.44474937  89.44474937 119.44474937 149.44474937]
# bat call time 6.974
# 1.0471975511965976 1.8401054725136305
# angles in hearing range [ 45.43027743  75.43027743 105.43027743 135.43027743 165.43027743]
# bat call time 7.08
# 1.0471975511965976 -1.0052196132266205
# angles in hearing range [-117.59484132  -87.59484132  -57.59484132  -27.59484132    2.40515868]
# bat call time 7.177
# 1.0471975511965976 -1.281259810381518
# angles in hearing range [-133.41077959 -103.41077959  -73.41077959  -43.41077959  -13.41077959]
# bat call time 7.282
# 1.0471975511965976 -1.032243724022591
# angles in hearing range [-119.14320882  -89.14320882  -59.14320882  -29.14320882    0.85679118]
# bat call time 7.378
# 1.0471975511965976 -0.7622313849086617
# angles in hearing range [-103.67264137  -73.67264137  -43.67264137  -13.67264137   16.32735863]
# bat call time 7.481
# 1.0471975511965976 -0.5162319688772848
# angles in hearing range [-89.57791307 -59.57791307 -29.57791307   0.42208693  30.42208693]
# bat call time 7.576
# 1.0471975511965976 -0.7502286926985271
# angles in hearing range [-102.98493776  -72.98493776  -42.98493776  -12.98493776   17.01506224]
# bat call time 7.667
# 1.0471975511965976 -0.9962233424688717
# angles in hearing range [-117.07939298  -87.07939298  -57.07939298  -27.07939298    2.92060702]
# bat call time 7.762
# 1.0471975511965976 -1.248260978585041
# angles in hearing range [-131.5200858 -101.5200858  -71.5200858  -41.5200858  -11.5200858]
# bat call time 7.859
# 1.0471975511965976 -1.5182405549351776
# angles in hearing range [-146.98877608 -116.98877608  -86.98877608  -56.98877608  -26.98877608]
# bat call time 7.962
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 8.06
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 8.152
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 8.212
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 8.253
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 8.311
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 8.357
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 8.41
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 8.463
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 8.516
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 8.574
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 8.621
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 8.667
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 8.714
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 8.757
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 8.816
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 8.863
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 8.921
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 8.976
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 9.02
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 9.273
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 9.33
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 9.389
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 9.437
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 9.481
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 9.54
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 9.589
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 9.646
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 9.687
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
#
# bat call time 9.739
# 1.0471975511965976 -1.7732421842795865
# angles in hearing range [-161.59929321 -131.59929321 -101.59929321  -71.59929321  -41.59929321]
# bat call time 9.791
# 1.0471975511965976 -1.6532470925503202
# angles in hearing range [-154.7240809 -124.7240809  -94.7240809  -64.7240809  -34.7240809]
# bat call time 9.844
# 1.0471975511965976 -1.389254918976787
# angles in hearing range [-139.59844353 -109.59844353  -79.59844353  -49.59844353  -19.59844353]
# bat call time 9.945
# total_time_taken_to_store_info: 0:01:24.116960
# average_time_per_loop 0:00:00.008412
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 83.5672 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/simulation/class_simulation.py
# Function: Simulation.run at line 65
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     65                                               def run(self):
#     66                                                   """Runs one instance of the simulation.
#     67                                                   After parsing the parameter file, it runs one instance of the simulation
#     68                                                   for those sets of parameters.
#     69                                                   """
#     70         2    8927139.0 4.46e+06      0.0          with open(self.dir_to_store + "bats_initial.pkl", "wb") as f:
#     71         1     158195.0 158195.0      0.0              pickle.dump(self.bats, f)
#     72         2      46100.0  23050.0      0.0          with open(self.dir_to_store + "obstacles_initial.pkl", "wb") as f:
#     73         1       3207.0   3207.0      0.0              pickle.dump(self.obstacles, f)
#     74         2      36119.0  18059.5      0.0          with open(self.dir_to_store + "jammers_initial.pkl", "wb") as f:
#     75         1       1762.0   1762.0      0.0              pickle.dump(self.jammers, f)
#     76
#     77         2       1484.0    742.0      0.0          num_steps = int(
#     78         1       2748.0   2748.0      0.0              self.parameters_df["SIM_DURATION"] / self.parameters_df["TIME_STEP"]
#     79                                                   )
#     80         1       5446.0   5446.0      0.0          start_timing = datetime.now()
#     81         1        505.0    505.0      0.0          list_time_taken_for_each_loop = []
#     82         1        268.0    268.0      0.0          save_time_of_last_iter = start_timing
#     83     10001    4016836.0    401.6      0.0          for step in range(num_steps):
#     84     20000   80777757.0   4038.9      0.1              self.time_elapsed = np.round(
#     85     10000    3863509.0    386.4      0.0                  step * self.parameters_df["TIME_STEP"],
#     86     10000    2301542.0    230.2      0.0                  self.rounding_based_on_time_step,
#     87                                                       )
#     88
#     89    916718  199402628.0    217.5      0.2              for sound in self.sound_objects:
#     90    906718 2801785891.0   3090.0      3.4                  sound.update(self.time_elapsed)
#     91
#     92     20000    9506440.0    475.3      0.0              for bat in self.bats:
#     93     10000     3.41e+10 3.41e+06     40.8                  bat.update(self.time_elapsed, self.sound_objects)
#     94
#     95     10000    4228696.0    422.9      0.0              for jammer in self.jammers:
#     96                                                           jammer.update(self.time_elapsed, self.sound_objects)
#     97
#     98     10000     3.78e+10 3.78e+06     45.2              self.handle_reflections(self.time_elapsed)
#     99
#    100    979697  319202035.0    325.8      0.4              self.sound_objects = [
#    101    969697  209968457.0    216.5      0.3                  s
#    102    979697  196454936.0    200.5      0.2                  for s in self.sound_objects
#    103    969697  197720556.0    203.9      0.2                  if s.active
#    104    968895  239760169.0    247.5      0.3                  and s.current_spl > self.parameters_df["HEARING_THRESHOLD"]
#    105                                                       ]
#    106
#    107     10000 4629643320.0 462964.3      5.5              self.history.append(self.convert_necessary_information_into_dict())
#    108     10000   28974985.0   2897.5      0.0              current_loop_time = datetime.now()
#    109     20000    7063785.0    353.2      0.0              list_time_taken_for_each_loop.append(
#    110     10000    5163500.0    516.4      0.0                  current_loop_time - save_time_of_last_iter
#    111                                                       )
#    112
#    113     10000    3130482.0    313.0      0.0              save_time_of_last_iter = current_loop_time
#    114     10000   67851645.0   6785.2      0.1              self.handle_data_storage_for_plotting(self.time_elapsed, False)
#    115     10000 2391157146.0 239115.7      2.9              self.handle_data_storage_for_plotting_pickle(self.time_elapsed, False)
#    116         1    3930564.0 3.93e+06      0.0          self.handle_data_storage_for_plotting(self.time_elapsed, True)
#    117         1  232518626.0 2.33e+08      0.3          self.handle_data_storage_for_plotting_pickle(self.time_elapsed, True)
#    118         1      99107.0  99107.0      0.0          print(f"total_time_taken_to_store_info: {save_time_of_last_iter-start_timing}")
#    119         1    1010646.0 1.01e+06      0.0          print(f"average_time_per_loop {np.mean(list_time_taken_for_each_loop)}")
#    120         1      31034.0  31034.0      0.0          print("DATA SAVED")

# %%
# %lprun -f Simulation.handle_reflections sim.run()
# Out:
# 1.0471975511965976 0.0
# angles in hearing range [-60. -30.   0.  30.  60.]
# bat call time 0.044
# 1.0471975511965976 0.12899876553699455
# angles in hearing range [-52.60891517 -22.60891517   7.39108483  37.39108483  67.39108483]
# bat call time 0.1
# 1.0471975511965976 -0.15000398741576107
# angles in hearing range [-68.59459539 -38.59459539  -8.59459539  21.40540461  51.40540461]
# bat call time 0.206
# 1.0471975511965976 -0.3930496492340286
# angles in hearing range [-82.52008604 -52.52008604 -22.52008604   7.47991396  37.47991396]
# bat call time 0.3
# 1.0471975511965976 -0.6330302156520543
# angles in hearing range [-96.26995966 -66.26995966 -36.26995966  -6.26995966  23.73004034]
# bat call time 0.393
# 1.0471975511965976 -0.8910201344933185
# angles in hearing range [-111.05169317  -81.05169317  -51.05169317  -21.05169317    8.94830683]
# bat call time 0.492
# 1.0471975511965976 -1.1489949382620488
# angles in hearing range [-125.83256064  -95.83256064  -65.83256064  -35.83256064   -5.83256064]
#
# bat call time 0.591
# 1.0471975511965976 -1.1489949382620488
# angles in hearing range [-125.83256064  -95.83256064  -65.83256064  -35.83256064   -5.83256064]
#
# bat call time 0.695
# 1.0471975511965976 -1.1489949382620488
# angles in hearing range [-125.83256064  -95.83256064  -65.83256064  -35.83256064   -5.83256064]
#
# bat call time 0.747
# 1.0471975511965976 -1.1489949382620488
# angles in hearing range [-125.83256064  -95.83256064  -65.83256064  -35.83256064   -5.83256064]
#
# bat call time 0.805
# 1.0471975511965976 -1.1489949382620488
# angles in hearing range [-125.83256064  -95.83256064  -65.83256064  -35.83256064   -5.83256064]
#
# bat call time 0.861
# 1.0471975511965976 -1.1489949382620488
# angles in hearing range [-125.83256064  -95.83256064  -65.83256064  -35.83256064   -5.83256064]
#
# bat call time 0.902
# 1.0471975511965976 -1.1489949382620488
# angles in hearing range [-125.83256064  -95.83256064  -65.83256064  -35.83256064   -5.83256064]
#
# bat call time 0.955
# 1.0471975511965976 -1.1489949382620488
# angles in hearing range [-125.83256064  -95.83256064  -65.83256064  -35.83256064   -5.83256064]
#
# bat call time 0.997
# 1.0471975511965976 -1.1489949382620488
# angles in hearing range [-125.83256064  -95.83256064  -65.83256064  -35.83256064   -5.83256064]
#
# bat call time 1.052
# 1.0471975511965976 -1.1489949382620488
# angles in hearing range [-125.83256064  -95.83256064  -65.83256064  -35.83256064   -5.83256064]
#
# bat call time 1.11
# 1.0471975511965976 -1.1489949382620488
# angles in hearing range [-125.83256064  -95.83256064  -65.83256064  -35.83256064   -5.83256064]
# bat call time 1.153
# 1.0471975511965976 -1.27497757956442
# angles in hearing range [-133.05083428 -103.05083428  -73.05083428  -43.05083428  -13.05083428]
# bat call time 1.208
# 1.0471975511965976 -1.5179696994820446
# angles in hearing range [-146.97325721 -116.97325721  -86.97325721  -56.97325721  -26.97325721]
# bat call time 1.302
# 1.0471975511965976 -1.7969778254254969
# angles in hearing range [-162.95924528 -132.95924528 -102.95924528  -72.95924528  -42.95924528]
# bat call time 1.408
# 1.0471975511965976 -2.052016902123778
# angles in hearing range [-177.57190798 -147.57190798 -117.57190798  -87.57190798  -57.57190798]
# bat call time 1.506
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 1.61
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 1.702
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 1.749
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 1.792
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 1.838
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 1.887
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 1.93
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 1.979
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.032
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.079
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.122
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.172
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.224
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.27
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.316
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.37
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.429
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.482
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.533
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.575
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.628
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.683
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.726
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.78
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.84
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.888
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 2.935
# total_time_taken_to_store_info: 0:00:28.172151
# average_time_per_loop 0:00:00.009391
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 12.1655 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/simulation/class_simulation.py
# Function: Simulation.handle_reflections at line 224
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    224                                               def handle_reflections(self, current_time):
#    225                                                   """Generates reflections of the sound objects.
#    226                                                   Soud objects can reflect off of obstacles and bats
#    227                                                   to generate EchoSound s.
#    228
#    229                                                   Args:
#    230                                                       current_time (float): Time, in seconds, for which the simualtion has been running.
#    231                                                   """
#    232      3000    1736123.0    578.7      0.0          new_echoes = []
#    233
#    234    345708   75753490.0    219.1      0.6          for sound in self.sound_objects:
#    235    342708   79997273.0    233.4      0.7              if not sound.active or not isinstance(sound, DirectSound):
#    236    340731   63038750.0    185.0      0.5                  continue
#    237
#    238      1977     516833.0    261.4      0.0              reflection_point = None
#    239      1977     412204.0    208.5      0.0              normal = None
#    240      1977     436854.0    221.0      0.0              obstacle_id = None
#    241
#    242      1977     593341.0    300.1      0.0              reflection_point_arr, normal_arr, obstacle_id_arr = [], [], []
#    243
#    244                                                       # check walls
#    245    824409  214168246.0    259.8      1.8              for wall_objects in self.wall_objects:
#    246                                                           # check only for jammer call emissions.
#    247
#    248    822432  223092428.0    271.3      1.8                  jammer_wall_check = sound.wall_id != wall_objects.wall_id
#    249                                                           # print(sound, sound.wall_id, wall_objects.wall_id)
#    250                                                           if (
#    251    822432 9486269842.0  11534.4     78.0                      sound.contains_point(wall_objects.position)
#    252     79872   27298629.0    341.8      0.2                      and f"wall_obstacle_{wall_objects.id}"
#    253     39936    9323552.0    233.5      0.1                      not in sound.reflected_obstacles
#    254     19968    4434471.0    222.1      0.0                      and jammer_wall_check
#    255                                                           ):
#    256     19968  400948695.0  20079.6      3.3                      normal = wall_objects.get_reflection_normal(sound.origin)
#    257     19968    5656286.0    283.3      0.0                      reflection_point = (
#    258     19968  374422781.0  18751.1      3.1                          wall_objects.position + normal * wall_objects.radius
#    259                                                               )
#    260     19968    8203914.0    410.9      0.1                      obstacle_id = f"wall_obstacle_{wall_objects.id}"
#    261
#    262     19968    6249598.0    313.0      0.1                      normal_arr.append(normal)
#    263     19968    5532041.0    277.0      0.0                      reflection_point_arr.append(reflection_point)
#    264     19968    5932832.0    297.1      0.0                      obstacle_id_arr.append(obstacle_id)
#    265                                                       # check obstacles
#    266      1977    1025617.0    518.8      0.0              for obstacle in self.obstacles:
#    267                                                           if (
#    268                                                               sound.contains_point(obstacle.position)
#    269                                                               and f"obstacle_{obstacle.id}" not in sound.reflected_obstacles
#    270                                                           ):
#    271                                                               normal = obstacle.get_reflection_normal(sound.origin)
#    272                                                               reflection_point = obstacle.position + normal * obstacle.radius
#    273                                                               obstacle_id = f"obstacle_{obstacle.id}"
#    274
#    275                                                               normal_arr.append(normal)
#    276                                                               reflection_point_arr.append(reflection_point)
#    277                                                               obstacle_id_arr.append(obstacle_id)
#    278
#    279                                                       # check other bats
#    280      3954    1587166.0    401.4      0.0              for bat in self.bats:
#    281                                                           if (
#    282      1977   25422179.0  12859.0      0.2                      sound.contains_point(bat.position)
#    283       147      61200.0    416.3      0.0                      and sound.emitter_id != bat.id
#    284                                                               and f"bat_{bat.id}" not in sound.reflected_obstacles
#    285                                                               and bat.is_bat_reflective_to_sound
#    286                                                           ):
#    287                                                               normal = (sound.origin - bat.position).normalize()
#    288                                                               reflection_point = bat.position + normal * bat.radius
#    289                                                               obstacle_id = f"bat_{bat.id}"
#    290
#    291                                                               normal_arr.append(normal)
#    292                                                               reflection_point_arr.append(reflection_point)
#    293                                                               obstacle_id_arr.append(obstacle_id)
#    294
#    295     21945    8388753.0    382.3      0.1              for i, reflection_point in enumerate(reflection_point_arr):
#    296     19968    5291297.0    265.0      0.0                  normal = normal_arr[i]
#    297     19968    4539052.0    227.3      0.0                  obstacle_id = obstacle_id_arr[i]
#    298     19968    5895855.0    295.3      0.0                  if obstacle_id not in sound.reflected_obstacles:
#    299     39936  246162959.0   6163.9      2.0                      time_of_creation = creation_time_calculation(
#    300     19968    4416162.0    221.2      0.0                          sound, reflection_point
#    301                                                               )
#    302
#    303     39936  702335671.0  17586.5      5.8                      echo = sound.create_echo(
#    304     19968    4941592.0    247.5      0.0                          reflection_point, time_of_creation, normal, obstacle_id
#    305                                                               )
#    306
#    307     19968    5631783.0    282.0      0.0                      if echo:
#    308                                                                   # mark this obstacle as reflected for the original sound
#    309     19968   74207827.0   3716.3      0.6                          echo.update(current_time)
#    310     19968    6701001.0    335.6      0.1                          sound.reflected_obstacles.add(obstacle_id)
#    311                                                                   # copy reflected obstacles to the echo
#    312     19968   61668859.0   3088.4      0.5                          echo.reflected_obstacles.update(sound.reflected_obstacles)
#    313     19968    5993852.0    300.2      0.0                          new_echoes.append(echo)
#    314
#    315      3000    7214907.0   2405.0      0.1          self.sound_objects.extend(new_echoes)

# %%
# %lprun -f Bat.update sim.run()
# Out:
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 0.037
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 0.088
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 0.144
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 0.187
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 0.229
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 0.277
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 0.319
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 0.363
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 0.415
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 0.467
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 0.514
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 0.57
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 0.617
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 0.677
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 0.733
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
#
# bat call time 0.777
# 1.0471975511965976 -2.325022165842275
# angles in hearing range [ 166.78604262 -163.21395738 -133.21395738 -103.21395738  -73.21395738]
# bat call time 0.836
# 1.0471975511965976 -2.187017142692532
# angles in hearing range [ 174.693148 -155.306852 -125.306852  -95.306852  -65.306852]
# bat call time 0.895
# 1.0471975511965976 -1.9380081901468447
# angles in hearing range [-171.03968996 -141.03968996 -111.03968996  -81.03968996  -51.03968996]
#
# bat call time 0.991
# 1.0471975511965976 -1.9380081901468447
# angles in hearing range [-171.03968996 -141.03968996 -111.03968996  -81.03968996  -51.03968996]
# bat call time 1.1
# 1.0471975511965976 -1.853999198033791
# angles in hearing range [-166.22632927 -136.22632927 -106.22632927  -76.22632927  -46.22632927]
# bat call time 1.141
# 1.0471975511965976 -1.5899803919023876
# angles in hearing range [-151.09916596 -121.09916596  -91.09916596  -61.09916596  -31.09916596]
# bat call time 1.242
# 1.0471975511965976 -1.3109761849371908
# angles in hearing range [-135.11340244 -105.11340244  -75.11340244  -45.11340244  -15.11340244]
#
# bat call time 1.348
# 1.0471975511965976 -1.3109761849371908
# angles in hearing range [-135.11340244 -105.11340244  -75.11340244  -45.11340244  -15.11340244]
#
# bat call time 1.453
# 1.0471975511965976 -1.3109761849371908
# angles in hearing range [-135.11340244 -105.11340244  -75.11340244  -45.11340244  -15.11340244]
#
# bat call time 1.506
# 1.0471975511965976 -1.3109761849371908
# angles in hearing range [-135.11340244 -105.11340244  -75.11340244  -45.11340244  -15.11340244]
# bat call time 1.565
# 1.0471975511965976 -1.2269863392416827
# angles in hearing range [-130.30113876 -100.30113876  -70.30113876  -40.30113876  -10.30113876]
# bat call time 1.606
# 1.0471975511965976 -0.9569662979590758
# angles in hearing range [-114.83013001  -84.83013001  -54.83013001  -24.83013001    5.16986999]
# bat call time 1.709
# 1.0471975511965976 -0.7199500894412756
# angles in hearing range [-101.25010159  -71.25010159  -41.25010159  -11.25010159   18.74989841]
# bat call time 1.801
# 1.0471975511965976 -0.47996738474844103
# angles in hearing range [-87.50010545 -57.50010545 -27.50010545   2.49989455  32.49989455]
# bat call time 1.894
# 1.0471975511965976 -0.2129387027726437
# angles in hearing range [-72.20048896 -42.20048896 -12.20048896  17.79951104  47.79951104]
# bat call time 1.996
# 1.0471975511965976 0.02407369899838034
# angles in hearing range [-58.62067865 -28.62067865   1.37932135  31.37932135  61.37932135]
# bat call time 2.088
# 1.0471975511965976 0.3000899401608098
# angles in hearing range [-42.80611295 -12.80611295  17.19388705  47.19388705  77.19388705]
# bat call time 2.193
# 1.0471975511965976 0.5341110469426918
# angles in hearing range [-29.39769122   0.60230878  30.60230878  60.60230878  90.60230878]
#
# bat call time 2.284
# 1.0471975511965976 0.5341110469426918
# angles in hearing range [-29.39769122   0.60230878  30.60230878  60.60230878  90.60230878]
#
# bat call time 2.393
# 1.0471975511965976 0.5341110469426918
# angles in hearing range [-29.39769122   0.60230878  30.60230878  60.60230878  90.60230878]
#
# bat call time 2.443
# 1.0471975511965976 0.5341110469426918
# angles in hearing range [-29.39769122   0.60230878  30.60230878  60.60230878  90.60230878]
#
# bat call time 2.502
# 1.0471975511965976 0.5341110469426918
# angles in hearing range [-29.39769122   0.60230878  30.60230878  60.60230878  90.60230878]
#
# bat call time 2.56
# 1.0471975511965976 0.5341110469426918
# angles in hearing range [-29.39769122   0.60230878  30.60230878  60.60230878  90.60230878]
#
# bat call time 2.608
# 1.0471975511965976 0.5341110469426918
# angles in hearing range [-29.39769122   0.60230878  30.60230878  60.60230878  90.60230878]
#
# bat call time 2.651
# 1.0471975511965976 0.5341110469426918
# angles in hearing range [-29.39769122   0.60230878  30.60230878  60.60230878  90.60230878]
# bat call time 2.697
# 1.0471975511965976 0.6331282799055686
# angles in hearing range [-23.72442167   6.27557833  36.27557833  66.27557833  96.27557833]
# bat call time 2.743
# 1.0471975511965976 0.8671255712628009
# angles in hearing range [-10.31736446  19.68263554  49.68263554  79.68263554 109.68263554]
# bat call time 2.834
# 1.0471975511965976 1.1191296365894856
# angles in hearing range [  4.1214049  34.1214049  64.1214049  94.1214049 124.1214049]
# bat call time 2.931
# total_time_taken_to_store_info: 0:00:38.457525
# average_time_per_loop 0:00:00.012819
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 10.7676 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/class_bats.py
# Function: Bat.update at line 81
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     81                                               def update(self, current_time, sound_objects):
#     82                                                   """Function to update bats with time.
#     83                                                   This function handles movement update of bat each time step.
#     84                                                   Also takes care of sound emission, detection of active sounds by the bats.
#     85                                                   Bat detections over time is also cleared and stored locally.
#     86
#     87                                                   Args:
#     88                                                       current_time (float): Time, in seconds, for which the simualtion has been running.
#     89                                                       sound_objects (EchoSound): direct and echo sounds that are currently active.
#     90                                                   """
#     91
#     92      3000  108244849.0  36081.6      1.0          self.update_movement()
#     93      3000   13733412.0   4577.8      0.1          self.emit_sounds(current_time, sound_objects)
#     94      3000     1.06e+10 3.55e+06     98.8          self.update_directon(current_time, sound_objects)
#     95
#     96      3000    3454086.0   1151.4      0.0          if self.id == 0 and self.time_since_directon_change == 0:
#     97                                                       print(current_time)

# %%
# %lprun -f Bat.update_directon sim.run()
# Out:
# 1.0471975511965976 0.0
# angles in hearing range [-60. -30.   0.  30.  60.]
# bat call time 0.076
# 1.0471975511965976 -0.12000217886446136
# angles in hearing range [-66.87561838 -36.87561838  -6.87561838  23.12438162  53.12438162]
# bat call time 0.129
# 1.0471975511965976 0.13198241801571742
# angles in hearing range [-52.43796448 -22.43796448   7.56203552  37.56203552  67.56203552]
# bat call time 0.226
# 1.0471975511965976 0.4019962589186217
# angles in hearing range [-36.96731098  -6.96731098  23.03268902  53.03268902  83.03268902]
# bat call time 0.329
# 1.0471975511965976 0.6690229929284217
# angles in hearing range [-21.66780611   8.33219389  38.33219389  68.33219389  98.33219389]
# bat call time 0.431
# 1.0471975511965976 0.9030364438796493
# angles in hearing range [ -8.25982302  21.74017698  51.74017698  81.74017698 111.74017698]
# bat call time 0.522
# 1.0471975511965976 1.1370359492112894
# angles in hearing range [  5.14736104  35.14736104  65.14736104  95.14736104 125.14736104]
# bat call time 0.613
# 1.0471975511965976 1.3740560985435761
# angles in hearing range [ 18.72761526  48.72761526  78.72761526 108.72761526 138.72761526]
# bat call time 0.705
# 1.0471975511965976 1.653038523195882
# angles in hearing range [ 34.71213075  64.71213075  94.71213075 124.71213075 154.71213075]
# bat call time 0.811
# 1.0471975511965976 1.9410240859331678
# angles in hearing range [ 51.21248806  81.21248806 111.21248806 141.21248806 171.21248806]
# bat call time 0.92
# 1.0471975511965976 2.2230569705853154
# angles in hearing range [  67.37178203   97.37178203  127.37178203  157.37178203 -172.62821797]
# bat call time 1.027
# 1.0471975511965976 2.50207443321783
# angles in hearing range [  83.35830505  113.35830505  143.35830505  173.35830505 -156.64169495]
# bat call time 1.133
# 1.0471975511965976 2.766089406649007
# angles in hearing range [  98.48524876  128.48524876  158.48524876 -171.51475124 -141.51475124]
# bat call time 1.234
# 1.0471975511965976 3.0300691662008323
# angles in hearing range [ 113.61017486  143.61017486  173.61017486 -156.38982514 -126.38982514]
# bat call time 1.335
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 1.427
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 1.519
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 1.576
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 1.619
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 1.678
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 1.732
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 1.777
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 1.818
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 1.864
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 1.912
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 1.969
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 2.261
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 2.303
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 2.359
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 2.41
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 2.466
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 2.52
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 2.579
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 2.62
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 2.666
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 2.717
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 2.768
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 2.815
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 2.873
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
#
# bat call time 2.922
# 1.0471975511965976 -3.0160943482372846
# angles in hearing range [ 127.19052323  157.19052323 -172.80947677 -142.80947677 -112.80947677]
# bat call time 2.972
# total_time_taken_to_store_info: 0:00:17.482889
# average_time_per_loop 0:00:00.005828
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 4.0875 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/class_bats.py
# Function: Bat.update_directon at line 329
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    329                                               def update_directon(self, current_time, sound_objects, temporal_masking_file):
#    330                                                   """rotate bat according to fix angular speed
#    331
#    332                                                   Args:
#    333                                                       current_time (float): Time, in seconds, for which the simualtion has been running.
#    334                                                       sound_objects (list): list containing detected sounds
#    335                                                   """
#    336      3000    1911555.0    637.2      0.0          self.time_since_directon_change += self.parameters_df["TIME_STEP"]
#    337
#    338      3000    4206281.0   1402.1      0.1          implement_snr = str2bool(self.parameters_df["IMPLEMENT_SNR"])
#    339      9000    3342710.0    371.4      0.1          min_sound_detection_fraction = self.parameters_df[
#    340      3000     795774.0    265.3      0.0              "MINIMUM_SOUND_DETECTION_FRACTION"
#    341      3000     690954.0    230.3      0.0          ][0]
#    342      6000    3181047.0    530.2      0.1          include_direct_sounds_in_response = str2bool(
#    343      3000    1052120.0    350.7      0.0              self.parameters_df["INCLUDE_DIRECT_SOUNDS_IN_RESPONSE"]
#    344                                                   )
#    345
#    346      6000    8291826.0   1382.0      0.2          hearing_angle_threshold = np.radians(
#    347      3000     986622.0    328.9      0.0              self.parameters_df["HEARING_ANGLE_THRESHOLD"]
#    348                                                   )
#    349
#    350      9000    2934742.0    326.1      0.1          direction_change_time_interval = self.parameters_df[
#    351      3000     812199.0    270.7      0.0              "TIME_DELAY_FOR_DIRECTION_CHANGE"
#    352      3000     685939.0    228.6      0.0          ][0]
#    353      6000    2392462.0    398.7      0.1          self.detections_for_directon_change.extend(
#    354      6000 3381198863.0 563533.1     82.7              self.given_sound_objects_return_sounds_at_bat_position(
#    355      3000     734640.0    244.9      0.0                  current_time, sound_objects
#    356                                                       )
#    357                                                   )
#    358
#    359                                                   if (
#    360      3000    1069422.0    356.5      0.0              self.time_since_directon_change >= direction_change_time_interval
#    361       270     150810.0    558.6      0.0              and len(self.detections_for_directon_change) != 0
#    362                                                   ):
#    363
#    364        40      10539.0    263.5      0.0              if implement_snr:
#    365        80  574388072.0 7.18e+06     14.1                  heard_sounds = given_sound_objects_return_detected_sounds(
#    366        40      10743.0    268.6      0.0                      self.detections_for_directon_change,
#    367        40      10355.0    258.9      0.0                      direction_change_time_interval,
#    368        40       8592.0    214.8      0.0                      hearing_angle_threshold,
#    369        40       8365.0    209.1      0.0                      temporal_masking_file,
#    370        40       8342.0    208.6      0.0                      min_sound_detection_fraction,
#    371        40      11565.0    289.1      0.0                      self.id,
#    372        40       9131.0    228.3      0.0                      include_direct_sounds_in_response,
#    373        40      12989.0    324.7      0.0                      self.parameters_df["CALL_DURATION"],
#    374        40      12354.0    308.9      0.0                      self.parameters_df["TIME_STEP"],
#    375        40      15178.0    379.4      0.0                      self.rounding_based_on_time_step,
#    376                                                           )
#    377                                                       else:
#    378                                                           heard_sounds = self.detections_for_directon_change
#    379
#    380        40     315666.0   7891.6      0.0              self.cleanup_sounds(current_time, heard_sounds)
#    381
#    382        40     120510.0   3012.8      0.0              self.modulate_speed_call_rate()
#    383
#    384        80   33752002.0 421900.0      0.8              self.next_direction, self.response_type = self.decide_next_direction(
#    385        40       9577.0    239.4      0.0                  heard_sounds
#    386                                                       )
#    387        40     548146.0  13703.6      0.0              self.detections_for_directon_change = []
#    388        40      30616.0    765.4      0.0              self.time_since_directon_change = -np.inf
#    389
#    390        40      22728.0    568.2      0.0              if self.response_type == "attraction":
#    391                                                           self.speed = self.parameters_df["BAT_FAST_SPEED"]
#    392                                                   elif (
#    393      2960     883184.0    298.4      0.0              self.time_since_directon_change >= direction_change_time_interval
#    394       230      80233.0    348.8      0.0              and len(self.detections_for_directon_change) != 0
#    395                                                   ):
#    396                                                       self.ipi_matrix = given_parameters_df_return_grid_matrix_zeros(
#    397                                                           self.parameters_df
#    398                                                       )[0]
#    399                                                       self.memory_window_sum_matrix = self.ipi_matrix.copy()
#    400
#    401      3000    1121399.0    373.8      0.0          rotation_speed = self.parameters_df["BAT_ROTATION_SPEED"]
#    402      3000     744464.0    248.2      0.0          rotation_speed_scaled_by_time_step = (
#    403      3000    1154828.0    384.9      0.0              rotation_speed * self.parameters_df["TIME_STEP"]
#    404                                                   )
#    405      6000   58963261.0   9827.2      1.4          self.rotate_towards_given_degree(
#    406      3000     811958.0    270.7      0.0              self.next_direction, rotation_speed_scaled_by_time_step
#    407                                                   )

# %%
# %lprun -f Bat.given_sound_objects_return_sounds_at_bat_position sim.run()
# Out:
# 1.0471975511965976 -2.890085434097766
# angles in hearing range [ 134.41030219  164.41030219 -165.58969781 -135.58969781 -105.58969781]
# bat call time 0.027
# 1.0471975511965976 3.1290952499561007
# angles in hearing range [ 119.28395152  149.28395152  179.28395152 -150.71604848 -120.71604848]
# bat call time 0.128
# 1.0471975511965976 2.8800972251358776
# angles in hearing range [ 105.01741559  135.01741559  165.01741559 -164.98258441 -134.98258441]
# bat call time 0.224
# 1.0471975511965976 2.643086032459515
# angles in hearing range [  91.43767455  121.43767455  151.43767455 -178.56232545 -148.56232545]
# bat call time 0.316
# 1.0471975511965976 2.3640928632927265
# angles in hearing range [  75.45254344  105.45254344  135.45254344  165.45254344 -164.54745656]
# bat call time 0.422
# 1.0471975511965976 2.09107277019523
# angles in hearing range [ 59.80964439  89.80964439 119.80964439 149.80964439 179.80964439]
# bat call time 0.526
# 1.0471975511965976 1.8090489116114084
# angles in hearing range [ 43.65086757  73.65086757 103.65086757 133.65086757 163.65086757]
# bat call time 0.633
# 1.0471975511965976 1.5210685751743023
# angles in hearing range [ 27.15080971  57.15080971  87.15080971 117.15080971 147.15080971]
# bat call time 0.742
# 1.0471975511965976 1.2720675790216336
# angles in hearing range [ 12.88410353  42.88410353  72.88410353 102.88410353 132.88410353]
# bat call time 0.838
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 0.931
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.034
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.079
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.12
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.166
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.225
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.279
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.333
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.385
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.442
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.502
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.552
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.596
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.646
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.691
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.737
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.791
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.839
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.887
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.946
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 1.992
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 2.042
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 2.101
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 2.152
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
#
# bat call time 2.206
# 1.0471975511965976 1.03208508484762
# angles in hearing range [ -0.86588054  29.13411946  59.13411946  89.13411946 119.13411946]
# bat call time 2.259
# 1.0471975511965976 1.1550668470912906
# angles in hearing range [  6.18045539  36.18045539  66.18045539  96.18045539 126.18045539]
# bat call time 2.313
# 1.0471975511965976 1.4220712263910678
# angles in hearing range [ 21.47867944  51.47867944  81.47867944 111.47867944 141.47867944]
# bat call time 2.415
# 1.0471975511965976 1.6740472543630962
# angles in hearing range [ 35.91584238  65.91584238  95.91584238 125.91584238 155.91584238]
# bat call time 2.512
# 1.0471975511965976 1.9380303184876744
# angles in hearing range [ 51.04095782  81.04095782 111.04095782 141.04095782 171.04095782]
# bat call time 2.613
# 1.0471975511965976 2.1840688908251313
# angles in hearing range [  65.13792961   95.13792961  125.13792961  155.13792961 -174.86207039]
# bat call time 2.708
# 1.0471975511965976 2.442069006718047
# angles in hearing range [  79.92024736  109.92024736  139.92024736  169.92024736 -160.07975264]
# bat call time 2.807
# 1.0471975511965976 2.730116710285608
# angles in hearing range [  96.42416508  126.42416508  156.42416508 -173.57583492 -143.57583492]
#
# bat call time 2.916
# total_time_taken_to_store_info: 0:00:43.617506
# average_time_per_loop 0:00:00.014539
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 11.6398 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/class_bats.py
# Function: Bat.given_sound_objects_return_sounds_at_bat_position at line 196
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    196                                               def given_sound_objects_return_sounds_at_bat_position(
#    197                                                   self, current_time, sound_objects
#    198                                               ):
#    199                                                   """given sounds generate list of sounds that a bat can hear
#    200
#    201                                                   Args:
#    202                                                       current_time (float): Time, in seconds, for which the simualtion has been running.
#    203                                                       sound_objects (list): List containing all active sounds in the simulation
#    204                                                       detect_self_call (Bool): If true, add self call to detected, else, skip self call.
#    205
#    206                                                   Returns:
#    207                                                       list: sound detections given time.
#    208                                                   """
#    209      3000    1528085.0    509.4      0.0          array_of_sound_detections = []
#    210                                                   # if bat is calling it shouldnt hear anything
#    211      3000     770972.0    257.0      0.0          is_bat_calling = (
#    212      3000    2218145.0    739.4      0.0              current_time < self.emit_times[-1] + self.parameters_df["CALL_DURATION"]
#    213                                                   )
#    214      3000     754120.0    251.4      0.0          if is_bat_calling:
#    215       111      47131.0    424.6      0.0              return array_of_sound_detections
#    216    728554  182530044.0    250.5      1.6          for sound in sound_objects:
#    217    725665 1724120127.0   2375.9     14.8              sound.update(current_time)
#    218
#    219    725665  172414073.0    237.6      1.5              is_sound_active = sound.active
#    220   1451330  352064393.0    242.6      3.0              is_sound_self_call = sound.emitter_id == self.id and isinstance(
#    221    725665  152323056.0    209.9      1.3                  sound, DirectSound
#    222                                                       )
#    223    725665  249552505.0    343.9      2.1              is_sound_reflected_from_self = sound.reflected_from == f"bat_{self.id}"
#    224
#    225                                                       if (
#    226    725665  164420308.0    226.6      1.4                  not is_sound_active
#    227    725624  159049386.0    219.2      1.4                  or is_sound_self_call
#    228    721097  155315630.0    215.4      1.3                  or is_sound_reflected_from_self
#    229                                                       ):
#    230      4568    1049692.0    229.8      0.0                  continue
#    231
#    232                                                       # sound can only be detected if bat is inside the sound wave
#    233    721097 7812142020.0  10833.7     67.1              if sound.contains_point(self.position):
#    234     12653  217144064.0  17161.5      1.9                  received_spl = sound.spl_at_receiver(self.position)
#    235
#    236     25306   17715622.0    700.1      0.2                  angle_between_sound_and_bat = sound.direction_vector.angle_between(
#    237     12653    3035499.0    239.9      0.0                      self.position
#    238                                                           )
#    239     25306   23110098.0    913.2      0.2                  hearing_directionality = call_directionality_factor(
#    240     12653    3378878.0    267.0      0.0                      A=self.parameters_df["HEARING_DIRECTIONALITY"],
#    241     12653    2684240.0    212.1      0.0                      theta=angle_between_sound_and_bat,
#    242                                                           )
#    243
#    244     12653    3638251.0    287.5      0.0                  received_spl += hearing_directionality
#    245     12653    2945330.0    232.8      0.0                  is_sound_audible = (
#    246     12653    3781004.0    298.8      0.0                      received_spl > self.parameters_df["HEARING_THRESHOLD"]
#    247                                                           )
#    248
#    249     12653    2894057.0    228.7      0.0                  if not is_sound_audible:
#    250      5123    1163310.0    227.1      0.0                      continue
#    251     15060    4048079.0    268.8      0.0                  array_of_sound_detections.append(
#    252      7530  221132164.0  29366.8      1.9                      self.convert_sound_to_dictionary(sound, current_time, received_spl)
#    253                                                           )
#    254      2889    2782827.0    963.2      0.0          return array_of_sound_detections

# %%
# %lprun -f Bat.detect_sounds sim.run()
# Out:
# 0.04
# 0.145
# 0.239
# 0.331
# 0.425
# 0.528
# 0.623
# 0.719
# 0.826
# 0.934
# total_time_taken_to_store_info: 0:01:01.460590
# average_time_per_loop 0:00:00.061461
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 26.9699 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/bats.py
# Function: Bat.detect_sounds at line 293
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    293                                               def detect_sounds(self, current_time, sound_objects):
#    294                                                   """Detects sound that are audible to the Bat
#    295                                                   Checks if a bat can hear a sound based on dbSpl of sound
#    296                                                   and position of bat.
#    297
#    298                                                   Args:
#    299                                                       current_time (float): Time, in seconds, for which the simualtion has been running.
#    300                                                       sound_objects (list): _description_
#    301                                                   """
#    302     20000   13119677.0    656.0      0.0          self.received_sounds.extend(
#    303     20000     2.69e+10 1.35e+06     99.9              self.given_sound_objects_return_sounds_at_bat_position(
#    304     10000    2935702.0    293.6      0.0                  current_time, sound_objects, detect_self_call=True
#    305                                                       )
#    306                                                   )
#    307     10000    5949727.0    595.0      0.0          self.ipi_matrix_timeseries.append(self.ipi_matrix)
#    308     20000    9934472.0    496.7      0.0          self.memory_window_to_store_grids_timeseries.append(
#    309     10000    3256816.0    325.7      0.0              self.memory_window_to_store_grids
#    310                                                   )

# %%
# %lprun -f Bat.given_sound_objects_return_sounds_at_bat_position sim.run()
# Out:
# 0.081
# 0.173
# 0.273
# 0.383
# 0.493
# 0.589
# 0.68
# 0.773
# 0.868
# 0.965
# total_time_taken_to_store_info: 0:00:46.572065
# average_time_per_loop 0:00:00.046572
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 33.3313 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/bats.py
# Function: Bat.given_sound_objects_return_sounds_at_bat_position at line 237
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    237                                               def given_sound_objects_return_sounds_at_bat_position(
#    238                                                   self, current_time, sound_objects, detect_self_call
#    239                                               ):
#    240                                                   """given sounds generate list of sounds that a bat can hear
#    241
#    242                                                   Args:
#    243                                                       current_time (float): Time, in seconds, for which the simualtion has been running.
#    244                                                       sound_objects (list): List containing all active sounds in the simulation
#    245                                                       detect_self_call (Bool): If true, add self call to detected, else, skip self call.
#    246
#    247                                                   Returns:
#    248                                                       list: sound detections given time.
#    249                                                   """
#    250     20000    6067018.0    303.4      0.0          array_of_sound_detections = []
#    251   6322062 1484552863.0    234.8      4.5          for sound in sound_objects:
#    252                                                       # sound.update(current_time)
#    253
#    254   6302062 1300644496.0    206.4      3.9              is_sound_active = sound.active
#    255   6302062 1413187057.0    224.2      4.2              is_sound_self_call = (
#    256   6932360 1519100848.0    219.1      4.6                  sound.emitter_id == self.id
#    257    630298  167401892.0    265.6      0.5                  and isinstance(sound, DirectSound)
#    258      6462    1620064.0    250.7      0.0                  and not detect_self_call
#    259                                                       )
#    260   6302062 1858376571.0    294.9      5.6              is_sound_reflected_from_self = sound.reflected_from == f"bat_{self.id}"
#    261
#    262                                                       if (
#    263   6302062 1370445022.0    217.5      4.1                  not is_sound_active
#    264   6199942 1339521757.0    216.1      4.0                  or is_sound_self_call
#    265   6196812 1301762966.0    210.1      3.9                  or is_sound_reflected_from_self
#    266                                                       ):
#    267    191018   42912557.0    224.7      0.1                  continue
#    268
#    269                                                       # sound can only be detected if bat is inside the sound wave
#    270   6111044      1.7e+10   2787.4     51.1              if sound.contains_point(self.position):
#    271    200074 1830836532.0   9150.8      5.5                  received_spl = sound.spl_at_receiver(self.position)
#    272
#    273    400148  299741581.0    749.1      0.9                  angle_between_sound_and_bat = sound.direction_vector.angle_between(
#    274    200074   49973802.0    249.8      0.1                      self.position
#    275                                                           )
#    276    400148  351359123.0    878.1      1.1                  hearing_directionality = call_directionality_factor(
#    277    200074   54695797.0    273.4      0.2                      A=self.parameters_df["HEARING_DIRECTIONALITY"],
#    278    200074   44931596.0    224.6      0.1                      theta=angle_between_sound_and_bat,
#    279                                                           )
#    280
#    281    200074   58550124.0    292.6      0.2                  received_spl += hearing_directionality
#    282    200074   47914351.0    239.5      0.1                  is_sound_audible = (
#    283    200074   59397674.0    296.9      0.2                      received_spl > self.parameters_df["HEARING_THRESHOLD"]
#    284                                                           )
#    285
#    286    200074   48969785.0    244.8      0.1                  if not is_sound_audible:
#    287     35588    8386872.0    235.7      0.0                      continue
#    288    328972  316570369.0    962.3      0.9                  array_of_sound_detections.append(
#    289    164486 1308116967.0   7952.8      3.9                      self.convert_sound_to_dictionary(sound, current_time, received_spl)
#    290                                                           )
#    291     20000   12384022.0    619.2      0.0          return array_of_sound_detections

# %%
# %lprun -f DirectSound.create_echo sim.run()
# Out:
# 0.068
# 0.177
# 0.28
# 0.389
# 0.487
# 0.583
# 0.679
# 0.778
# 0.871
# 0.98
# total_time_taken_to_store_info: 0:00:47.700767
# average_time_per_loop 0:00:00.047701
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 0.16916 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/sounds.py
# Function: DirectSound.create_echo at line 174
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    174                                               def create_echo(self, point, current_time, normal, reflected_from):
#    175                                                   """Handles EchoSound creation by the sound object.
#    176                                                   Creates an echo at the specified point.
#    177
#    178                                                   Args:
#    179                                                       point (Vector): point of reflection of sound
#    180                                                       current_time (float): time, in seconds, for which the simualtion has been running.
#    181                                                       normal (Vector): Normal vector from the object that the sound reflects from.
#    182                                                       reflected_from (string): The id of the object the sound reflects from.
#    183
#    184                                                   Returns:
#    185                                                       EchoSound: The generated EchoSound object.
#    186                                                   """
#    187      5547    1947933.0    351.2      1.2          if self.has_reflected:
#    188                                                       return None
#    189
#    190     11094   10317210.0    930.0      6.1          angle_between_sound_and_reflection_point = self.direction_vector.angle_between(
#    191      5547    1185002.0    213.6      0.7              point
#    192                                                   )
#    193     11094   11659569.0   1051.0      6.9          call_directionality = call_directionality_factor(
#    194      5547    1678842.0    302.7      1.0              A=self.parameters_df["CALL_DIRECTIONALITY"],
#    195      5547    1132619.0    204.2      0.7              theta=angle_between_sound_and_reflection_point,
#    196                                                   )
#    197
#    198      5547    2091753.0    377.1      1.2          object_type = reflected_from[0:4]
#    199      5547    1503133.0    271.0      0.9          if object_type == "wall":
#    200       395     149721.0    379.0      0.1              reflection_loss = self.parameters_df["REFLECTION_LOSS_WALL"]
#    201                                                   else:
#    202      5152    1510032.0    293.1      0.9              reflection_loss = self.parameters_df["REFLECTION_LOSS"]
#    203
#    204      5547   14040137.0   2531.1      8.3          distance_between_sound_and_echo = self.origin.distance_to(point)
#    205                                                   # print(distance_between_sound_and_echo)
#    206     11094    3877306.0    349.5      2.3          distance_effect_for_echoes = 20 * math.log10(
#    207      5547    1401975.0    252.7      0.8              distance_between_sound_and_echo / 1
#    208                                                   )
#    209      5547    1135150.0    204.6      0.7          spl_corrected_for_width = (
#    210     16641    4575359.0    274.9      2.7              self.initial_spl
#    211      5547    1267005.0    228.4      0.7              - distance_effect_for_echoes
#    212                                                       - (
#    213     11094    3009622.0    271.3      1.8                  self.parameters_df["AIR_ABSORPTION"]
#    214      5547    1089196.0    196.4      0.6                  * distance_between_sound_and_echo
#    215                                                       )
#    216                                                   )
#    217
#    218      5547    1810167.0    326.3      1.1          reflected_spl = spl_corrected_for_width - reflection_loss + call_directionality
#    219      5547    1882961.0    339.5      1.1          if reflected_spl < self.parameters_df["HEARING_THRESHOLD"]:
#    220                                                       return None
#    221
#    222                                                   # if reflected_spl > spl_corrected_for_width:
#    223                                                   #     print(self.current_spl)
#    224                                                   #     print(
#    225                                                   #         f"reflected spl {reflected_spl}, self spl {self.current_spl}, spl corrected {spl_corrected_for_width}, reflection_loss {reflection_loss}, call directionality {call_directionality}"
#    226                                                   #     )
#    227
#    228     11094   83297987.0   7508.4     49.2          echo = EchoSound(
#    229      5547    1295105.0    233.5      0.8              parameters_df=self.parameters_df,
#    230      5547    1147116.0    206.8      0.7              origin=point,
#    231      5547    1056528.0    190.5      0.6              creation_time=current_time,
#    232      5547    1346378.0    242.7      0.8              emitter_id=self.emitter_id,
#    233      5547    1081227.0    194.9      0.6              initial_spl=reflected_spl,
#    234      5547    1268265.0    228.6      0.7              parent_creation_time=self.creation_time,
#    235      5547    1142840.0    206.0      0.7              reflection_count=1,
#    236      5547    1114814.0    201.0      0.7              reflected_from=reflected_from,
#    237      5547    1063816.0    191.8      0.6              direction_vector=normal,
#    238                                                   )
#    239      5547    4310767.0    777.1      2.5          echo.reflected_obstacles.update(self.reflected_obstacles)
#    240      5547    3770912.0    679.8      2.2          return echo

# %%
# %lprun -f Vector.distance_to sim.run()
# Out:
# 0.014
# 0.071
# 0.166
# 0.263
# 0.354
# 0.461
# 0.565
# 0.67
# 0.763
# 0.868
# 0.974
# total_time_taken_to_store_info: 0:00:23.452646
# average_time_per_loop 0:00:00.023453
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 6.19428 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/supporting_files/vectors.py
# Function: Vector.distance_to at line 54
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     54                                               def distance_to(self, other):
#     55                                                   """measure distance between two vectors
#     56
#     57                                                   Args:
#     58                                                       other (Vector): compute distance to this vector
#     59
#     60                                                   Returns:
#     61                                                       float: distance
#     62                                                   """
#     63   3307440 6194276569.0   1872.8    100.0          return (self - other).magnitude()

# %%
# %lprun -f Bat.update_directon sim.run()
# Out:
# 0.067
# 0.167
# 0.26
# 0.364
# 0.471
# 0.563
# 0.669
# 0.765
# 0.87
# 0.962
# total_time_taken_to_store_info: 0:00:37.323196
# average_time_per_loop 0:00:00.037323
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 16.3697 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/bats.py
# Function: Bat.update_directon at line 411
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    411                                               def update_directon(self, current_time, sound_objects):
#    412                                                   """rotate bat according to fix angular speed
#    413
#    414                                                   Args:
#    415                                                       current_time (float): Time, in seconds, for which the simualtion has been running.
#    416                                                       sound_objects (list): list containing detected sounds
#    417                                                   """
#    418     10000    5517565.0    551.8      0.0          self.time_since_directon_change += self.parameters_df["TIME_STEP"]
#    419                                                   # self.reaction_time += self.parameters_df["TIME_STEP"]
#    420     30000   10835231.0    361.2      0.1          direction_change_time_interval = self.parameters_df[
#    421     10000    3020197.0    302.0      0.0              "TIME_DELAY_FOR_DIRECTION_CHANGE"
#    422     10000    2571761.0    257.2      0.0          ][0]
#    423     20000   10750659.0    537.5      0.1          self.detections_for_directon_change.extend(
#    424     20000     1.51e+10 756382.1     92.4              self.given_sound_objects_return_sounds_at_bat_position(
#    425     10000    2512866.0    251.3      0.0                  current_time, sound_objects, detect_self_call=False
#    426                                                       )
#    427                                                   )
#    428
#    429                                                   if (
#    430     10000    3559664.0    356.0      0.0              self.time_since_directon_change >= direction_change_time_interval
#    431       101      47090.0    466.2      0.0              and len(self.detections_for_directon_change) != 0
#    432                                                   ):
#    433                                                       # print(len(self.detections_for_directon_change))
#    434       101      29519.0    292.3      0.0              if self.implement_snr:
#    435       202 1057806489.0 5.24e+06      6.5                  heard_sounds = given_sound_objects_return_detected_sounds(
#    436       101      23640.0    234.1      0.0                      self.detections_for_directon_change,
#    437       101      22055.0    218.4      0.0                      direction_change_time_interval,
#    438       101      25608.0    253.5      0.0                      self.hearing_angle_threshold,
#    439       101      29246.0    289.6      0.0                      self.temporal_masking_file,
#    440       101      23824.0    235.9      0.0                      self.min_sound_detection_fraction,
#    441       101      28600.0    283.2      0.0                      self.id,
#    442       101      25547.0    252.9      0.0                      self.include_direct_sounds_in_response,
#    443       101      54138.0    536.0      0.0                      self.parameters_df["CALL_DURATION"],
#    444       101      28838.0    285.5      0.0                      self.parameters_df["TIME_STEP"],
#    445       101      24512.0    242.7      0.0                      self.rounding_based_on_time_step,
#    446                                                           )
#    447                                                       else:
#    448                                                           heard_sounds = self.detections_for_directon_change
#    449
#    450       101     106015.0   1049.7      0.0              if self.any_consistent_sound == "no":
#    451                                                           self.speed = self.parameters_df["BAT_FAST_SPEED"]
#    452                                                           self.call_rate = self.parameters_df["CALL_RATE_FAST"]
#    453                                                       else:
#    454       101      82267.0    814.5      0.0                  self.speed = self.parameters_df["BAT_SPEED"]
#    455       101      43805.0    433.7      0.0                  self.call_rate = self.parameters_df["CALL_RATE"]
#    456
#    457       202   31846315.0 157655.0      0.2              self.next_direction, self.response_type = self.decide_next_direction(
#    458       101      23302.0    230.7      0.0                  heard_sounds
#    459                                                       )
#    460       101    2572934.0  25474.6      0.0              self.detections_for_directon_change = []
#    461       101      83173.0    823.5      0.0              self.time_since_directon_change = -np.inf
#    462                                                       # self.reaction_time = 0
#    463                                                       # self.reaction_state = "responding"
#    464       101     376897.0   3731.7      0.0              if self.next_direction != self.direction.normalize():
#    465       101      40055.0    396.6      0.0                  self.responding_to_direction = (
#    466       101      30653.0    303.5      0.0                      self.next_direction.x,
#    467       101      23025.0    228.0      0.0                      self.next_direction.y,
#    468                                                           )
#    469                                                       else:
#    470                                                           self.responding_to_direction = (np.nan, np.nan)
#    471
#    472       101      37764.0    373.9      0.0              if self.response_type == "attraction":
#    473                                                           self.speed = self.parameters_df["BAT_FAST_SPEED"]
#    474                                                   elif (
#    475      9899    2862451.0    289.2      0.0              self.time_since_directon_change >= direction_change_time_interval
#    476                                                       and len(self.detections_for_directon_change) != 0
#    477                                                   ):
#    478                                                       self.ipi_matrix = given_parameters_df_return_grid_matrix_zeros(
#    479                                                           self.parameters_df
#    480                                                       )[0]
#    481                                                       self.memory_window_sum_matrix = self.ipi_matrix.copy()
#    482                                                       # print("oh this part running rrn")
#    483                                                   # if self.reaction_time >= self.parameters_df["REACTION_TIME"]:
#    484                                                   #     print("aaa")
#    485                                                   #     self.reaction_state = None
#    486                                                   #     self.reaction_time = -np.inf
#    487     10000    3574792.0    357.5      0.0          rotation_speed = self.parameters_df["BAT_ROTATION_SPEED"]
#    488     10000    2482008.0    248.2      0.0          rotation_speed_scaled_by_time_step = (
#    489     10000    3638656.0    363.9      0.0              rotation_speed * self.parameters_df["TIME_STEP"]
#    490                                                   )
#    491     20000   94326001.0   4716.3      0.6          self.rotate_towards_given_degree(
#    492     10000    2934867.0    293.5      0.0              self.next_direction, rotation_speed_scaled_by_time_step
#    493                                                   )

# %%
# %lprun -f Bat.given_sound_objects_return_sounds_at_bat_position sim.run()
# Out:
# 0.057
# 0.159
# 0.269
# 0.372
# 0.48
# 0.584
# 0.694
# 0.789
# 0.892
# 0.985
# total_time_taken_to_store_info: 0:01:08.229439
# average_time_per_loop 0:00:00.068229
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 49.163 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/bats.py
# Function: Bat.given_sound_objects_return_sounds_at_bat_position at line 237
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    237                                               def given_sound_objects_return_sounds_at_bat_position(
#    238                                                   self, current_time, sound_objects, detect_self_call
#    239                                               ):
#    240                                                   """given sounds generate list of sounds that a bat can hear
#    241
#    242                                                   Args:
#    243                                                       current_time (float): Time, in seconds, for which the simualtion has been running.
#    244                                                       sound_objects (list): List containing all active sounds in the simulation
#    245                                                       detect_self_call (Bool): If true, add self call to detected, else, skip self call.
#    246
#    247                                                   Returns:
#    248                                                       list: sound detections given time.
#    249                                                   """
#    250     20000    6288049.0    314.4      0.0          array_of_sound_detections = []
#    251   9507294 2274881703.0    239.3      4.6          for sound in sound_objects:
#    252                                                       # sound.update(current_time)
#    253
#    254   9487294 1940815377.0    204.6      3.9              is_sound_active = sound.active
#    255   9487294 2096041041.0    220.9      4.3              is_sound_self_call = (
#    256  10436114 2350260081.0    225.2      4.8                  sound.emitter_id == self.id
#    257    948820  237378180.0    250.2      0.5                  and isinstance(sound, DirectSound)
#    258     16350    4185940.0    256.0      0.0                  and not detect_self_call
#    259                                                       )
#    260   9487294 2992958844.0    315.5      6.1              is_sound_reflected_from_self = sound.reflected_from == f"bat_{self.id}"
#    261
#    262                                                       if (
#    263   9487294 2139981111.0    225.6      4.4                  not is_sound_active
#    264   9377654 1999857024.0    213.3      4.1                  or is_sound_self_call
#    265   9369576 2051351996.0    218.9      4.2                  or is_sound_reflected_from_self
#    266                                                       ):
#    267    260768   58571202.0    224.6      0.1                  continue
#    268
#    269                                                       # sound can only be detected if bat is inside the sound wave
#    270   9226526     2.57e+10   2782.0     52.2              if sound.contains_point(self.position):
#    271    211033 1971464574.0   9342.0      4.0                  received_spl = sound.spl_at_receiver(self.position)
#    272
#    273    422066  300032721.0    710.9      0.6                  angle_between_sound_and_bat = sound.direction_vector.angle_between(
#    274    211033   51723834.0    245.1      0.1                      self.position
#    275                                                           )
#    276    422066  383198681.0    907.9      0.8                  hearing_directionality = call_directionality_factor(
#    277    211033   56694351.0    268.7      0.1                      A=self.parameters_df["HEARING_DIRECTIONALITY"],
#    278    211033   46955132.0    222.5      0.1                      theta=angle_between_sound_and_bat,
#    279                                                           )
#    280
#    281    211033   62083975.0    294.2      0.1                  received_spl += hearing_directionality
#    282    211033   49441143.0    234.3      0.1                  is_sound_audible = (
#    283    211033   62293763.0    295.2      0.1                      received_spl > self.parameters_df["HEARING_THRESHOLD"]
#    284                                                           )
#    285
#    286    211033   53215889.0    252.2      0.1                  if not is_sound_audible:
#    287     19418    4546493.0    234.1      0.0                      continue
#    288    383230  617087716.0   1610.2      1.3                  array_of_sound_detections.append(
#    289    191615 1670104861.0   8715.9      3.4                      self.convert_sound_to_dictionary(sound, current_time, received_spl)
#    290                                                           )
#    291     20000   13301628.0    665.1      0.0          return array_of_sound_detections

# %%
# %lprun -f given_sound_objects_return_detected_sounds sim.run()
# Out:
# 0.011
# 0.058
# 0.162
# 0.267
# 0.362
# 0.457
# 0.549
# 0.652
# 0.752
# 0.853
# 0.958
# total_time_taken_to_store_info: 0:00:30.601223
# average_time_per_loop 0:00:00.030601
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 1.47369 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/supporting_files/snr_implementation.py
# Function: given_sound_objects_return_detected_sounds at line 498
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    498                                           def given_sound_objects_return_detected_sounds(
#    499                                               sound_objects,
#    500                                               time_threshold_post_call,
#    501                                               angle_threshold,
#    502                                               temporal_masking_df,
#    503                                               minimum_sound_detection_fraction,
#    504                                               focal_bat,
#    505                                               include_direct_sounds,
#    506                                               call_duration,
#    507                                               sim_time_step,
#    508                                               sim_rounding,
#    509                                           ):
#    510                                               """given list of sounds, returns the list of sounds that are detected.
#    511                                               if the sound to masker profile is atleast minimum_sound_detection_fraction
#    512                                               then the sound is considered to be detected.
#    513
#    514                                               Args:
#    515                                                   sound_objects (list): contains all the sound objects exracted from output files
#    516                                                   time_threshold_post_call (float): _description_
#    517                                                   angle_threshold (float): :math:`\\pm` angle in radians of the bat's hearing field
#    518                                                   dir_of_temporal_masking_fn_file (str): directory of temporal masking function file
#    519                                                   minimum_sound_detection_fraction (float): fraction of sound to masker ratio that
#    520                                                                                           needs to be above masking tolerance for detection
#    521                                                   focal_bat (int): id of the bat that is hearing the sounds
#    522                                                   include_direct_sounds (bool): False if direct sounds shouldn't be considered
#    523                                                                               in snr calculations.
#    524
#    525                                               Returns:
#    526                                                   list: contains heard sounds
#    527                                               """
#    528
#    529       214  124980438.0 584020.7      8.5      parsed_sounds = parse_sounds(
#    530       107      71168.0    665.1      0.0          sound_objects,
#    531       107      29832.0    278.8      0.0          time_threshold_post_call,
#    532       107      22595.0    211.2      0.0          angle_threshold,
#    533       107      24719.0    231.0      0.0          focal_bat,
#    534       107      26691.0    249.4      0.0          include_direct_sounds,
#    535       107      26965.0    252.0      0.0          call_duration,
#    536                                               )
#    537       107      59763.0    558.5      0.0      if len(parsed_sounds) == 0:
#    538                                                   return []
#    539       214  174711408.0 816408.4     11.9      parsed_serialized_sounds = filter_sounds_based_on_total_profile(
#    540       107      32422.0    303.0      0.0          parsed_sounds, sim_time_step, sim_rounding
#    541                                               )
#    542       214  154036707.0 719797.7     10.5      parsed_serialized_sounds = serialize_sound_info(
#    543       107      34133.0    319.0      0.0          parsed_serialized_sounds, sim_time_step, sim_rounding
#    544                                               )
#    545                                               # print(len(parsed_serialized_sounds))
#    546       107      63048.0    589.2      0.0      if len(parsed_serialized_sounds) == 0:
#    547                                                   return []
#    548
#    549                                               # print(len(parsed_serialized_sounds))
#    550
#    551       107      35673.0    333.4      0.0      heard_sounds = []
#    552      2173     626660.0    288.4      0.0      for focal_sound in parsed_serialized_sounds:
#    553      4132 1015470284.0 245757.6     68.9          if is_signal_heard(
#    554      2066     481771.0    233.2      0.0              focal_sound,
#    555      2066     439051.0    212.5      0.0              parsed_serialized_sounds,
#    556      2066     427287.0    206.8      0.0              temporal_masking_df,
#    557      2066     421611.0    204.1      0.0              minimum_sound_detection_fraction,
#    558      2066     416319.0    201.5      0.0              sim_time_step,
#    559      2066     460752.0    223.0      0.0              sim_rounding,
#    560                                                   ):
#    561      2066     708114.0    342.7      0.0              heard_sounds.append(focal_sound)
#    562
#    563       107      78820.0    736.6      0.0      return heard_sounds

# %%
# %lprun -f is_signal_heard sim.run()
# Out:
# 0.056
# 0.157
# 0.254
# 0.353
# 0.41
# 0.469
# 0.579
# 0.672
# 0.776
# 0.885
# 0.994
# total_time_taken_to_store_info: 0:00:44.520025
# average_time_per_loop 0:00:00.044520
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 0.738789 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/supporting_files/snr_implementation.py
# Function: is_signal_heard at line 438
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    438                                           def is_signal_heard(
#    439                                               focal_sound,
#    440                                               parsed_sounds,
#    441                                               temporal_masking_df,
#    442                                               minimum_sound_detection_fraction,
#    443                                               sim_time_step,
#    444                                               sim_rounding,
#    445                                           ):
#    446                                               """given sound and list of potentially masking sound, return if sound is heard or not
#    447                                               if the sound to masker profile is atleast minimum_sound_detection_fraction
#    448                                               then the sound is considered to be detected.
#    449
#    450                                               Args:
#    451                                                   focal_sound (dict): focal sound
#    452                                                   parsed_sounds (list): list of all sounds that can potentially mask
#    453                                                   dir_of_temporal_masking_fn_file (str): directory of temporal masking function file
#    454                                                   minimum_sound_detection_fraction (float): fraction of sound to masker ratio
#    455                                                                                           that needs to be above masking tolerance
#    456                                                                                           for detection
#    457
#    458                                               Returns:
#    459                                                   bool: true if sound is heard, else false
#    460                                               """
#    461                                               # temporal_masking_df = pd.read_csv(dir_of_temporal_masking_fn_file)
#    462      1612     489187.0    303.5      0.1      time_extent_of_temporal_masking_fn_file = [
#    463      1612    9064192.0   5622.9      1.2          np.max(temporal_masking_df["timegap_ms"]),
#    464      1612    7687534.0   4768.9      1.0          np.min(temporal_masking_df["timegap_ms"]),
#    465                                               ]
#    466      3224  522023290.0 161917.9     70.7      focal_sound_masker_ratio, time_axis_given_sound = generate_sound_profile(
#    467      1612     391322.0    242.8      0.1          parsed_sounds,
#    468      1612     408227.0    253.2      0.1          focal_sound,
#    469      1612     374578.0    232.4      0.1          time_extent_of_temporal_masking_fn_file,
#    470      1612     364621.0    226.2      0.0          sim_time_step,
#    471      1612     376297.0    233.4      0.1          sim_rounding,
#    472                                               )
#    473      3224  179856999.0  55786.9     24.3      temporal_masking_thresholds = get_temporal_masking_function_based_on_sound(
#    474      1612     405458.0    251.5      0.1          time_axis_given_sound,
#    475      1612     359308.0    222.9      0.0          temporal_masking_df,
#    476      1612     420183.0    260.7      0.1          focal_sound["duration"],
#    477      1612     398184.0    247.0      0.1          sim_time_step,
#    478                                               )
#    479      1612     435395.0    270.1      0.1      count_total = 0
#    480      1612     366742.0    227.5      0.0      count_focal_sound_greater_masking_threshold = 0
#    481
#    482     14360    3824298.0    266.3      0.5      for i, temporal_masking_threshold in enumerate(temporal_masking_thresholds):
#    483     12748    3827498.0    300.2      0.5          if focal_sound_masker_ratio[i] >= temporal_masking_threshold:
#    484     11524    2678029.0    232.4      0.4              count_focal_sound_greater_masking_threshold += 1
#    485     12748    2846883.0    223.3      0.4          count_total += 1
#    486
#    487      1612     408296.0    253.3      0.1      percent_of_focal_sound_detected = (
#    488      1612     478639.0    296.9      0.1          count_focal_sound_greater_masking_threshold / count_total
#    489                                               )
#    490      1612     436491.0    270.8      0.1      if percent_of_focal_sound_detected >= minimum_sound_detection_fraction:
#    491      1612     867008.0    537.8      0.1          return True
#    492                                               if percent_of_focal_sound_detected < minimum_sound_detection_fraction:
#    493                                                   return False
#    494                                               else:
#    495                                                   raise ValueError("Percent focal sound is messed up!")

# %%
# %lprun -f generate_sound_profile sim.run()
# Out:
# 0.032
# 0.088
# 0.191
# 0.299
# 0.408
# 0.513
# 0.613
# 0.722
# 0.825
# 0.927
# total_time_taken_to_store_info: 0:00:30.913781
# average_time_per_loop 0:00:00.030914
# DATA SAVED
# Timer unit: 1e-09 s
#
# Total time: 0.668881 s
# File: /home/adityamoger/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/supporting_files/snr_implementation.py
# Function: generate_sound_profile at line 278
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    278                                           def generate_sound_profile(
#    279                                               list_of_sounds,
#    280                                               focal_sound_object,
#    281                                               time_extent_of_temporal_masking_fn_file,
#    282                                               sim_time_step,
#    283                                               sim_rounding,
#    284                                           ):
#    285                                               """given a focal sound and list of all sounds, generate focal_sound_to_masker_ratio
#    286                                               computes both the focal_sound profile and masker sound profiles.
#    287
#    288
#    289                                               Args:
#    290                                                   list_of_sounds (list): all sounds that can potentially mask the focal sound
#    291                                                   focal_sound_object (dict): focal sound
#    292                                                   time_extent_of_temporal_masking_fn_file (list): first entry is the time before a call to consider
#    293                                                       second entry is the
#    294
#    295                                               Returns:
#    296                                                   list,list: returns the focal sound to masker ratio and
#    297                                                   the time axis centered around focal sound
#    298                                               """
#    299                                               # the - sim_time_step / 2 is cause numpy sometimes includes the last term wtf kms
#    300      1895     600042.0    316.6      0.1      start_time_of_focal_sound = focal_sound_object["time"]
#    301      1895     529338.0    279.3      0.1      ipi_start_time = focal_sound_object["bat_last_call_time"]
#    302
#    303      1895     607891.0    320.8      0.1      duration_before_call_to_consider = start_time_of_focal_sound - ipi_start_time
#    304
#    305                                               # time_extent_of_temporal_masking_fn_file = [0.025, -0.001]
#    306
#    307      3790   13415262.0   3539.6      2.0      start_of_time_axis = np.min(
#    308      1895     535542.0    282.6      0.1          [time_extent_of_temporal_masking_fn_file[0], duration_before_call_to_consider]
#    309                                               )
#    310      1895     477446.0    252.0      0.1      end_of_time_axis = (
#    311      1895     854966.0    451.2      0.1          -focal_sound_object["duration"] + time_extent_of_temporal_masking_fn_file[1]
#    312                                               )
#    313
#    314      1895     488361.0    257.7      0.1      time_extent_of_masking_global_time = [
#    315      1895     575403.0    303.6      0.1          start_time_of_focal_sound - start_of_time_axis,
#    316      1895     552989.0    291.8      0.1          start_time_of_focal_sound - end_of_time_axis,
#    317                                               ]
#    318
#    319      3790    8845999.0   2334.0      1.3      time_axis_given_sound = np.round(
#    320      3790    3405223.0    898.5      0.5          np.arange(
#    321      1895     431817.0    227.9      0.1              start_of_time_axis,
#    322      1895     704504.0    371.8      0.1              end_of_time_axis - sim_time_step / 2,
#    323      1895     479338.0    252.9      0.1              -sim_time_step,
#    324                                                   ),
#    325      1895     476059.0    251.2      0.1          sim_rounding,
#    326                                               )
#    327
#    328      1895    1970003.0   1039.6      0.3      matrix_with_spls = np.zeros(shape=(len(time_axis_given_sound), len(list_of_sounds)))
#    329
#    330     44262   11867932.0    268.1      1.8      for i, sound in enumerate(list_of_sounds):
#    331     42367   10069752.0    237.7      1.5          is_sound_not_focal_sound = (
#    332     42367   41861830.0    988.1      6.3              sound["sound_object_id"] != focal_sound_object["sound_object_id"]
#    333                                                   )
#    334     82839   64845272.0    782.8      9.7          if is_sound_not_focal_sound and sound_within_time_interval(
#    335     40472    9338889.0    230.7      1.4              sound, time_extent_of_masking_global_time
#    336                                                   ):
#    337     64220  145563233.0   2266.6     21.8              time_of_sound_wrt_focal_sound = np.round(
#    338     32110    8883044.0    276.6      1.3                  sound["time"] - focal_sound_object["time"], sim_rounding
#    339                                                       )
#    340
#    341     32110    9147794.0    284.9      1.4              time_intervals_to_add_intensity = (
#    342     32110   30004939.0    934.4      4.5                  sound["occurance_times"] - focal_sound_object["time"]
#    343                                                       )
#    344                                                       # np.arange(
#    345                                                       #     time_of_sound_wrt_focal_sound,
#    346                                                       #     time_of_sound_wrt_focal_sound + sound["duration"] + sim_time_step / 2,
#    347                                                       #     sim_time_step,
#    348                                                       # )
#    349
#    350     80652   40336449.0    500.1      6.0              for j, time_step in enumerate(time_intervals_to_add_intensity):
#    351     48542   71106743.0   1464.8     10.6                  index_to_put_spl = np.where(time_axis_given_sound == time_step)[0]
#    352
#    353     48542   43121904.0    888.3      6.4                  matrix_with_spls[index_to_put_spl, i] = sound["all_spl_values"][j]
#    354
#    355      3790    2698039.0    711.9      0.4      masker_profile = np.array(
#    356      1895  133909408.0  70664.6     20.0          [find_sum_of_db(i, sim_rounding) for i in matrix_with_spls]
#    357                                               )
#    358      1895     529361.0    279.3      0.1      focal_sound_profile = (
#    359      1895    7817951.0   4125.6      1.2          np.ones(shape=(len(time_axis_given_sound))) * focal_sound_object["received_spl"]
#    360                                               )
#    361
#    362      1895    1235683.0    652.1      0.2      focal_sound_masker_ratio = focal_sound_profile - masker_profile
#    363      1895    1592206.0    840.2      0.2      return focal_sound_masker_ratio, time_axis_given_sound

# %%
# %lprun -f generate_sound_profile sim.run()
# Out:
# /home/adityamoger/anaconda3/envs/cocktail_3_dynamic_model/lib/python3.12/site-packages/line_profiler/ipython_extension.py:97: UserWarning: Adding a function with a `.__wrapped__` attribute. You may want to profile the wrapped function by adding `generate_sound_profile.__wrapped__` instead.
#   profile = LineProfiler(*funcs)
# 0.003
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('lprun', '-f generate_sound_profile sim.run()')
#
# File ~/anaconda3/envs/cocktail_3_dynamic_model/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2504, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2502     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2503 with self.builtin_trap:
# -> 2504     result = fn(*args, **kwargs)
#    2506 # The code below prevents the output from being displayed
#    2507 # when using magics with decorator @output_can_be_silenced
#    2508 # when the last Python token in the expression is a ';'.
#    2509 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/anaconda3/envs/cocktail_3_dynamic_model/lib/python3.12/site-packages/line_profiler/ipython_extension.py:130, in LineProfilerMagics.lprun(self, parameter_s)
#     128 try:
#     129     try:
# --> 130         profile.runctx(arg_str, global_ns, local_ns)
#     131         message = ""
#     132     except SystemExit:
#
# File ~/anaconda3/envs/cocktail_3_dynamic_model/lib/python3.12/site-packages/line_profiler/profiler_mixin.py:496, in ByCountProfilerMixin.runctx(self, cmd, globals, locals)
#     494 self.enable_by_count()
#     495 try:
# --> 496     exec(cmd, globals, locals)
#     497 finally:
#     498     self.disable_by_count()
#
# File <string>:1
#
# File ~/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/simulation_and_plotting/simulation.py:88, in Simulation.run(self)
#      85     sound.update(self.time_elapsed)
#      87 for bat in self.bats:
# ---> 88     bat.update(self.time_elapsed, self.sound_objects)
#      90 self.handle_reflections(self.time_elapsed)
#      92 self.history.append(
#      93     {
#      94         "time": np.round(
#    (...)    131     }
#     132 )
#
# File ~/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/bats.py:133, in Bat.update(self, current_time, sound_objects)
#     129 # if current_time < 0.5:
#     130 #     print(self.ipi_matrix)
#     131 # print(self.ipi_matrix_timeseries)
#     132 if not self.kill_movement:
# --> 133     self.update_directon(current_time, sound_objects)
#     134     self.cleanup_sounds(current_time)
#     135     self.detect_sounds(current_time, sound_objects)
#
# File ~/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/agents/bats.py:435, in Bat.update_directon(self, current_time, sound_objects)
#     429 if (
#     430     self.time_since_directon_change >= direction_change_time_interval
#     431     and len(self.detections_for_directon_change) != 0
#     432 ):
#     433     # print(len(self.detections_for_directon_change))
#     434     if self.implement_snr:
# --> 435         heard_sounds = given_sound_objects_return_detected_sounds(
#     436             self.detections_for_directon_change,
#     437             direction_change_time_interval,
#     438             self.hearing_angle_threshold,
#     439             self.temporal_masking_file,
#     440             self.min_sound_detection_fraction,
#     441             self.id,
#     442             self.include_direct_sounds_in_response,
#     443             self.parameters_df["CALL_DURATION"][0],
#     444             self.parameters_df["TIME_STEP"][0],
#     445             self.rounding_based_on_time_step,
#     446         )
#     447     else:
#     448         heard_sounds = self.detections_for_directon_change
#
# File ~/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/supporting_files/snr_implementation.py:555, in given_sound_objects_return_detected_sounds(sound_objects, time_threshold_post_call, angle_threshold, temporal_masking_df, minimum_sound_detection_fraction, focal_bat, include_direct_sounds, call_duration, sim_time_step, sim_rounding)
#     553 heard_sounds = []
#     554 for focal_sound in parsed_serialized_sounds:
# --> 555     if is_signal_heard(
#     556         focal_sound,
#     557         parsed_serialized_sounds,
#     558         temporal_masking_df,
#     559         minimum_sound_detection_fraction,
#     560         sim_time_step,
#     561         sim_rounding,
#     562     ):
#     563         heard_sounds.append(focal_sound)
#     565 return heard_sounds
#
# File ~/Documents/GitHub/dynamic_model_of_cocktail_party_nightmare/dynamic_model/supporting_files/snr_implementation.py:468, in is_signal_heard(focal_sound, parsed_sounds, temporal_masking_df, minimum_sound_detection_fraction, sim_time_step, sim_rounding)
#     463 # temporal_masking_df = pd.read_csv(dir_of_temporal_masking_fn_file)
#     464 time_extent_of_temporal_masking_fn_file = [
#     465     np.max(temporal_masking_df["timegap_ms"]),
#     466     np.min(temporal_masking_df["timegap_ms"]),
#     467 ]
# --> 468 focal_sound_masker_ratio, time_axis_given_sound = generate_sound_profile(
#     469     parsed_sounds,
#     470     focal_sound,
#     471     time_extent_of_temporal_masking_fn_file,
#     472     sim_time_step,
#     473     sim_rounding,
#     474 )
#     475 temporal_masking_thresholds = get_temporal_masking_function_based_on_sound(
#     476     time_axis_given_sound,
#     477     temporal_masking_df,
#     478     focal_sound["duration"],
#     479     sim_time_step,
#     480 )
#     481 count_total = 0
#
# File ~/anaconda3/envs/cocktail_3_dynamic_model/lib/python3.12/site-packages/numba/core/dispatcher.py:424, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     420         msg = (f"{str(e).rstrip()} \n\nThis error may have been caused "
#     421                f"by the following argument(s):\n{args_str}\n")
#     422         e.patch_message(msg)
# --> 424     error_rewrite(e, 'typing')
#     425 except errors.UnsupportedError as e:
#     426     # Something unsupported is present in the user code, add help info
#     427     error_rewrite(e, 'unsupported_error')
#
# File ~/anaconda3/envs/cocktail_3_dynamic_model/lib/python3.12/site-packages/numba/core/dispatcher.py:365, in _DispatcherBase._compile_for_args.<locals>.error_rewrite(e, issue_type)
#     363     raise e
#     364 else:
# --> 365     raise e.with_traceback(None)
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# Untyped global name 'sound_within_time_interval': Cannot determine Numba type of <class 'function'>
#
# File "dynamic_model/supporting_files/snr_implementation.py", line 336:
# def generate_sound_profile(
#     <source elided>
#         )
#         if is_sound_not_focal_sound and sound_within_time_interval(
#         ^
#
# During: Pass nopython_type_inference
#
# This error may have been caused by the following argument(s):
# - argument 0: Cannot type list element type <class 'dict'>
# - argument 1: Cannot determine Numba type of <class 'dict'>
